# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName('genderClassifier').getOrCreate()

# %%
from pyspark.ml.clustering import KMeans

#df = spark.read.format("csv").option("header", "true").load("sum_tab_1.csv")

train_pro = spark.read.csv("file:///home/hadoop/sum_tab_1.csv", header = True, inferSchema = True)
#train_pro = spark.read.format("csv").load("file:///home/hadoop/sum_tab_1.csv")


train_pro.head()

# %%
# !ls
# Out:
# sparkML-labelNoise  spencer-dev.ipynb  train_pro.csv  Untitled.ipynb

# %%
# !find "$(pwd)" train_pro.csv
# Out:
# /home/hadoop
# /home/hadoop/.gitconfig
# /home/hadoop/.ssh
# /home/hadoop/.ssh/authorized_keys
# /home/hadoop/.bash_profile
# /home/hadoop/.ipynb_checkpoints
# /home/hadoop/.ipynb_checkpoints/spencer-dev-checkpoint.ipynb
# /home/hadoop/.ipynb_checkpoints/Untitled-checkpoint.ipynb
# /home/hadoop/.aws
# /home/hadoop/.aws/config
# /home/hadoop/.local
# /home/hadoop/.local/share
# /home/hadoop/.local/share/jupyter
# /home/hadoop/.local/share/jupyter/nbsignatures.db
# /home/hadoop/.local/share/jupyter/notebook_secret
# /home/hadoop/.local/share/jupyter/runtime
# /home/hadoop/.local/share/jupyter/runtime/notebook_cookie_secret
# /home/hadoop/.local/share/jupyter/runtime/kernel-03c16ed7-9cf4-4c7d-a97b-d0cbda473e45.json
# /home/hadoop/.local/share/jupyter/runtime/nbserver-29107.json
# /home/hadoop/.local/share/jupyter/runtime/nbserver-23110.json
# /home/hadoop/.local/share/jupyter/runtime/kernel-87c5b5ef-ba4e-45dd-a117-3e15636d2db6.json
# ...
