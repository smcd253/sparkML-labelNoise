# %%
# !ls
# Numerical Imporst 
import pandas as pd
import numpy as np

# Plotting 
import matplotlib.pyplot as plt
import seaborn as sns

# Python 
import os

# Sklearn metrics 
from sklearn.metrics import f1_score # f1_score(y_true, y_pred)
# Out:
# README.txt     sum_tab_1.csv  test_pro.tsv   train_pro.tsv
# Untitled.ipynb test_cli.tsv   train_cli.tsv

# %%
df_train_pro = pd.read_csv(f'{os.getcwd()}/train_pro.tsv', 
                           delim_whitespace=True,
                           low_memory=False,
                          )
df_test_pro = pd.read_csv(f'{os.getcwd()}/test_pro.tsv', 
                           delim_whitespace=True,
                           low_memory=False,
                          )
df_train_cli = pd.read_csv(f'{os.getcwd()}/train_cli.tsv', 
                           delimiter='\t',
                           low_memory=False,
                          ).T
df_test_cli = pd.read_csv(f'{os.getcwd()}/test_cli.tsv', 
                           delimiter='\t',
                           low_memory=False,
                          ).T
df_train_mislabel = pd.read_csv(f'{os.getcwd()}/sum_tab_1.csv', 
                           low_memory=False,
                          )
pd.set_option("display.max_rows", 100)
pd.set_option("display.max_columns", 100)
df_train_cli.head(-1)
# Out:
#                 0           1           2           3           4   \
# sample  Training_1  Training_2  Training_3  Training_4  Training_5
# gender      Female      Female        Male      Female      Female
#
#                 5           6           7           8            9   \
# sample  Training_6  Training_7  Training_8  Training_9  Training_10
# gender        Male      Female      Female      Female       Female
#
#                  10           11           12           13           14  \
# sample  Training_11  Training_12  Training_13  Training_14  Training_15
# gender       Female       Female       Female       Female         Male
#
#                  15           16           17           18           19  \
# sample  Training_16  Training_17  Training_18  Training_19  Training_20
# gender       Female       Female       Female       Female         Male
#
#                  20           21           22           23           24  \
# sample  Training_21  Training_22  Training_23  Training_24  Training_25
# gender       Female       Female       Female         Male         Male
#
#                  25           26           27           28           29  \
# sample  Training_26  Training_27  Training_28  Training_29  Training_30
# gender       Female       Female         Male       Female         Male
#
#                  30           31           32           33           34  \
# sample  Training_31  Training_32  Training_33  Training_34  Training_35
# gender       Female         Male         Male       Female       Female
#
#                  35           36           37           38           39  \
# sample  Training_36  Training_37  Training_38  Training_39  Training_40
# gender         Male         Male       Female       Female         Male
#
#                  40           41           42           43           44  \
# sample  Training_41  Training_42  Training_43  Training_44  Training_45
# gender       Female       Female       Female         Male         Male
#
#                  45           46           47           48           49  \
# sample  Training_46  Training_47  Training_48  Training_49  Training_50
# gender       Female       Female       Female         Male       Female
#
#                  50           51           52           53           54  \
# sample  Training_51  Training_52  Training_53  Training_54  Training_55
# gender         Male       Female         Male       Female       Female
#
#                  55           56           57           58           59  \
# sample  Training_56  Training_57  Training_58  Training_59  Training_60
# gender       Female       Female       Female       Female         Male
#
#                  60           61           62           63           64  \
# sample  Training_61  Training_62  Training_63  Training_64  Training_65
# gender         Male       Female       Female       Female         Male
#
#                  65           66           67           68           69  \
# sample  Training_66  Training_67  Training_68  Training_69  Training_70
# gender       Female       Female       Female         Male         Male
#
#                  70           71           72           73           74  \
# sample  Training_71  Training_72  Training_73  Training_74  Training_75
# gender       Female       Female         Male         Male       Female
#
#                  75           76           77           78           79
# sample  Training_76  Training_77  Training_78  Training_79  Training_80
# gender         Male       Female       Female         Male       Female
